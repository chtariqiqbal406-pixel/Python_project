# %% [markdown]
# <a href="https://colab.research.google.com/github/chtariqiqbal406-pixel/Python_project/blob/main/Regression_Model_my.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from google.colab import drive
drive.mount("/content/Drive")
df = pd.read_csv("/content/Drive/MyDrive/Breast.csv")
df.head()

# Scatter plot
sns.scatterplot(x='radius_mean',  y='texture_mean', data=df)
plt.title("Scatter Plot for Correlation")
plt.show()

# Reshape for sklearn
X = df[['radius_mean']]
y = df['texture_mean']

# Model training
model = LinearRegression()
model.fit(X, y)

# Prediction
y_pred = model.predict(X)
# Evaluate the model
mse = mean_squared_error(X, y)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y, y_pred)


# Step 7: Display performance metrics
print("Model Performance on Test Data:")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")

# Plot regression line
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Predicted')
plt.title("Linear Regression Fit")
plt.xlabel("radius_mean")
plt.ylabel("texture_mean")
plt.legend()
plt.grid(True)
plt.show()

# Print the intercept and coefficient
print("Y-intercept:", model.intercept_)
print("Coefficient:", model.coef_[0])

# Print the regression equation
print(f"Regression Equation: texture_mean = {model.coef_[0]:.2f} * radius_mean + {model.intercept_:.2f}")

# Correlation value
corr = df['radius_mean'].corr(df['texture_mean'])
print("Correlation Coefficient:", corr)
print("R² Score:", r2_score(y, y_pred))
# Out:
# Drive already mounted at /content/Drive; to attempt to forcibly remount, call drive.mount("/content/Drive", force_remount=True).
# Model Performance on Test Data:
# Mean Squared Error (MSE): 47.72
# Root Mean Squared Error (RMSE): 6.91
# Mean Absolute Error (MAE): 3.12
# Y-intercept: 13.70697015982554
# Coefficient: 0.3951697500916246
# Regression Equation: texture_mean = 0.40 * radius_mean + 13.71
# Correlation Coefficient: 0.323781890927733
# R² Score: 0.10483471289273838
