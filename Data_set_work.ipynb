# %% [markdown]
# <a href="https://colab.research.google.com/github/chtariqiqbal406-pixel/Python_project/blob/main/Data_set_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/Drive")
# Out:
# Mounted at /content/Drive

# %%
import pandas as pd

df = pd.read_csv("/content/Drive/MyDrive/Titanicdataset.csv")
df.head()
#1. Display the first 5 rows of the dataset.

print("First 5 Rows:\n",df.head())

#2. Display the last 3 rows of the dataset.
print("Last 3 Rows:\n",df.tail(3))
print()
#3. Show the data shape, column names and data types.
print("No of rows and column:",df.shape)
print()
print("Name of column:\n",df.columns)
print()
print("Data type of column:\n",df.dtypes)
#4. Count the number of missing values in each column.
print("No. of missing values:\n",df.isnull().sum())
# Out:
# First 5 Rows:
#     PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked predicted embarked
# 0   330911   7.8292   NaN        Q                  Q
# 1   363272   7.0000   NaN        S                  S
# 2   240276   9.6875   NaN        Q                  Q
# 3   315154   8.6625   NaN        S                  S
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/Drive/MyDrive/Titanicdataset.csv")
df.head()
print("5. Get only the Name and Sex columns.\n")
print(df[["Name","Sex"]])
print()
print("6. Get the PassengerId, Name, and Fare columns of the first 10 rows.\n")
print(df.loc[0:9,["PassengerId","Name","Fare"]])
# Out:
# 5. Get only the Name and Sex columns.
#
#                                              Name     Sex
# 0                                Kelly, Mr. James    male
# 1                Wilkes, Mrs. James (Ellen Needs)  female
# 2                       Myles, Mr. Thomas Francis    male
# 3                                Wirz, Mr. Albert    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..                                            ...     ...
# 413                            Spector, Mr. Woolf    male
# 414                  Oliva y Ocana, Dona. Fermina  female
# 415                  Saether, Mr. Simon Sivertsen    male
# 416                           Ware, Mr. Frederick    male
# 417                      Peter, Master. Michael J    male
#
# [418 rows x 2 columns]
#
# 6. Get the PassengerId, Name, and Fare columns of the first 10 rows.
#
#    PassengerId                                          Name     Fare
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/Drive/MyDrive/Titanicdataset.csv")
print("7. Select all rows where Pclass = 1.\n")
print(df.loc[df["Pclass"]==1])
print()
print("8. Select all rows where Sex = &quot;female&quot; and Survived = 1:\n")
print(df.loc[(df["Sex"]=="female") & (df["Survived"]==1)])
print()
print("9. Select the Age of passengers whose Fare>100:\n")
print(df[df["Fare"]>100][["Age","Fare"]])
# Out:
# 7. Select all rows where Pclass = 1.
#
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ...
