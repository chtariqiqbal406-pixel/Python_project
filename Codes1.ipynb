# %%
BY=int(input("Enter Your age"))
Age=2025-BY
print("your bage is=",Age)
# Out:
# Enter Your age1987
# your bage is= 38

# %%
Principal_amount=float(input("Enter the amount"))
rate_of_intrest=float(input("Enter the rate"))
Time=float(input("Enter the time"))
simple_intrest=(Principal_amount*rate_of_intrest*Time)/100
print("your simple intrest is=",simple_intrest)
# Out:
# Enter the amount50000
# Enter the rate6
# Enter the time5
# your simple intrest is= 15000.0

# %%
#Area of Rectangle
L=float(input("Enter the length"))
W=float(input("Enter the width"))
Area=L*W
perimeter=2*(L+W)
print("Area of Rectangle=",Area)
print("Perimeter of Rectangle=",perimeter)
# Out:
# Enter the length25
# Enter the width65
# Area of Rectangle= 1625.0
# Perimeter of Rectangle= 180.0

# %%
#Area of circle
r=float(input("Enter the radius"))
Area=3.14*r**2
circumference=2*3.14*r
print("Area of circle=",Area)
print("circumference is",circumference)
# Out:
# Enter the radius64
# Area of circle= 12861.44
# circumference is 401.92

# %%
a=float(input("Enter the first number"))
b=float(input("Enter the second number"))
c=float(input("Enter the third number"))
average=(a+b+c)/3
print("average of three number=",average)
# Out:
# Enter the first number45
# Enter the second number67
# Enter the third number87
# average of three number= 66.33333333333333

# %%
Tempreture= float(input("enter the tempreture"))
Fahrenheit=(Tempreture*9/5)+32
print("Tempreture in Fahrenheit=",Fahrenheit)
# Out:
# enter the tempreture65
# Tempreture in Fahrenheit= 149.0
