# %%
code=int(input("enter the number"))
if code%2==0:
  print("Number is Even")
else:
  print("Number is odd")
# Out:
# enter the number56
# Number is Even

# %%
Num=int(input("Enter the number"))
if Num<0 and Num%2==0:
    print("The number is negative and even")
elif Num<0 and Num%2==1:
   print("The number is negative and odd")
elif Num>0 and Num%2==0:
    print("The number is positive and even")
else:
    print("The number is positive and odd"
# Out:
# Enter the number-45
# The number is negative and odd

# %%
Marks_Fsc=int(input("Enter Fsc Marks"))
Marks_Test=int(input("Enter Test Marks"))
Age=int(input("Enter your age"))
if Marks_Fsc>=60 and Marks_Test>=70 and Age>=18:
    print("Congratulation you have got admission")
else:
    print("Sorry you have not got admission")
    if Marks_Fsc <60:
        print("Your marks are blow in Fsc")
    if Marks_Test <70:
        print("Your marks are blow in Test")
    if Age <18:
        print("your are under age")
# Out:
# Enter Fsc Marks55
# Enter Test Marks79
# Enter your age19
# Sorry you have not got admission
# Your marks are blow in Fsc
