# %% [markdown]
# Q1: Create a dictionary with 3 fruits and their prices. Print the price of one fruit.

# %%
dict={"apple":25,"banana":30,"orange":40}
print(f"The price of fruit is ={dict["banana"]}")
# Out:
# The price of fruit is =30

# %% [markdown]
# Q2: Make a dictionary of 3 students with their names as keys and marks as values. Print all the
# keys (names).

# %%
my_dicts={"Burhan":56,"Ayyan":72,"Hanan":68}
print(my_dicts.keys())
# Out:
# dict_keys(['Burhan', 'Ayyan', 'Hanan'])

# %% [markdown]
# Q3: Create a dictionary of 5 countries and their capitals. Ask the user to input a country and print
# its capital.

# %%
Dicts={"pakistan":"Islamabad","United States":"Washington","United Kingdom":"London","Germany":"Berlin"}
Country_Name=input("enter the country name")
print(f"The capital of {Country_Name} is {Dicts[Country_Name]}")
# Out:
# enter the country nameUnited Kingdom
# The capital of United Kingdom is London

# %% [markdown]
# Q4: Create a dictionary with numbers as keys and their squares as values (for numbers 1 to 5).

# %%
dics={1:1,2:4,3:9,4:16,5:25}
key=int(input("enter the key"))
print(f"The square of {key} is {dics[key]}")
# Out:
# enter the key3
# The square of 3 is 9

# %% [markdown]
# Q5: Create a dictionary of a person with keys: name, age, city. Change the city to another one
# and print the updated dictionary.

# %%
Dic={"Name":"Burhan","Age":12,"City":"Lahore"}
Dic["City"]="Bahawalpur"
print(f"Updated Dic :{Dic}")
# Out:
# Updated Dic :{'Name': 'Burhan', 'Age': 12, 'City': 'Bahawalpur'}

# %% [markdown]
# Q6: Create a dictionary of items in a store with their quantities. Add a new item to the dictionary
# and print it.

# %%
dict={"apple": 10, "banana": 20, "orange": 15}
dict["grapes"] = 25
print(f"Updated dictionary: {dict}")
# Out:
# Updated dictionary: {'apple': 10, 'banana': 20, 'orange': 15, 'grapes': 25}

# %% [markdown]
# Q7: Create a dictionary of student marks. Find and print the student with the highest marks.

# %%
dict={"Burhan":56,"Ayyan":72,"Hanan":68}
max_marks=max(dict.values())
print(f"Maximum Marks={max_marks}")
# Out:
# Maximum Marks=72

# %% [markdown]
# Q8: Make a nested dictionary:
# students = {
# &quot;Ali&quot;: {&quot;age&quot;: 20, &quot;grade&quot;: &quot;A&quot;},
# &quot;Sara&quot;: {&quot;age&quot;: 22, &quot;grade&quot;: &quot;B&quot;}}
# Print only the grades of all students.

# %%
students = { "Burhan": {"age": 20, "grade": "A"}, "Ayyan": {"age": 22, "grade": "B"},"Hanan":{"age":15,"grade":"C"}}

for i in students.values():
  print(i["grade"])
# Out:
# A
# B
# C

# %% [markdown]
# Q9: Create a dictionary and remove one key-value pair using pop(). Print the updated
# dictionary.

# %%
dict={"apple": 10, "banana": 20, "orange": 15}
delet=dict.pop("banana")
print(f"updated dict:{dict}")
# Out:
# updated dict:{'apple': 10, 'orange': 15}
