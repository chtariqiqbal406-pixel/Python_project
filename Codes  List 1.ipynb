# %% [markdown]
# Q1: Create a list of 5 fruits. Print the first and last fruit.

# %%
list=["apple","orange","banana","mengo","melon"]
print("Names of all fruits:",list)
print("Name of firest fruit:",list[0])
print("Name of last fruit:",list[-1])
# Out:
# Names of all fruits: ['apple', 'orange', 'banana', 'mengo', 'melon']
# Name of firest fruit: apple
# Name of last fruit: melon

# %% [markdown]
# Q2: Create a list of numbers [10, 20, 30, 40, 50]. Print the sum of all numbers in the list.

# %%
list=[10,20,30,40,50]
print(f"Sum of all numbers in list:{sum(list)}")
# Out:
# Sum of all numbers in list:150

# %% [markdown]
# Q3: Make a list of 4 colors. Replace the 2nd color with a new one and print the updated
# list.

# %%
list=["red","green","yellow","blue"]
list[1]="c green"
print(" list after updateng colure:",list)
# Out:
#  list after updateng colure: ['red', 'c green', 'yellow', 'blue']

# %% [markdown]
# Q4: Create a list [5, 10, 15, 20, 25]. Remove the number 15 and print the updated list.

# %%
list=[5,10,15,20,25,30]
list.pop(2)
print("Updating list:",list)
# Out:
# Updating list: [5, 10, 20, 25, 30]
